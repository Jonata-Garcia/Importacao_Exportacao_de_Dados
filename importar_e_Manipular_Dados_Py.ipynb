# %% [markdown]
# <a href="https://colab.research.google.com/github/Jonata-Garcia/Importacao_Exportacao_de_Dados/blob/main/importar_e_Manipular_Dados_Py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()

#files.dowload("dados.xlsx")

for fn in uploaded.keys():
  print('Arquivo "{name}" com tamanho de {length} bytes'.format(
name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-40937c77-adc5-4ba8-a80f-48abf002ac0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40937c77-adc5-4ba8-a80f-48abf002ac0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

from google.colab import files

# The file 'dados.xlsx' was not found.
# The previously uploaded file was '20Nomes.xlsx', and in this cell, '20Nomes (1).xlsx' was uploaded.
# I will read the file '20Nomes (1).xlsx'.
Dados1 = pd.read_excel('20Nomes (1).xlsx')
print(Dados1)
print(Dados1.shape)
# !ls # Mostralista de arquivos
# Out:
#                  Nome
# 0        Sofia Santos
# 1      Miguel Pereira
# 2      Alice Oliveira
# 3          Davi Costa
# 4     Laura Rodrigues
# 5       Lucas Almeida
# 6     Maria Fernandes
# 7         Pedro Silva
# 8         Julia Gomes
# 9     Gabriel Martins
# 10  Isabella Carvalho
# 11    Matheus Ribeiro
# 12       Manuela Lima
# 13       Enzo Cardoso
# 14        Luiza Souza
# 15    Gustavo Barbosa
# 16           Ana Dias
# 17         João Rocha
# 18   Valentina Mendes
# 19    Bernardo Castro
# (20, 1)
# '20Nomes (1).xlsx'  'Cópia de Odonto.Py'	     sample_data
#  20Nomes.xlsx	    'importar e exportar Dados Py'

# %%
import pandas as pd

# The file 'growth.csv' was not found.
# Based on the output of the first cell, the uploaded file is '20Nomes.xlsx'.
# I will read the file '20Nomes.xlsx'.
Dados2 = pd.read_excel("20Nomes.xlsx")
print(Dados2.head())
print(Dados2.shape)
# Out:
#               Nome
# 0     Sofia Santos
# 1   Miguel Pereira
# 2   Alice Oliveira
# 3       Davi Costa
# 4  Laura Rodrigues
# (20, 1)
